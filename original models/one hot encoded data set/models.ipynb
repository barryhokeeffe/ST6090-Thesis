# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
baseline = 0.3842665269335408

# %%
dt_scaled = 0.5784989019609094
dt_pca = 0.6152968516629987

# %%
gb_scaled = 0.40456035087218933
gb_pca = 0.45040393782855387

# %%
lr_scaled = 0
lr_pca = 0.4791668000217274

# %%
mlp_scaled = 0.9162607186905268
mlp_pca = 0.647633986148747

# %%
rf_scaled = 0.4384365880292739
rf_pca = 0.47946601228015917

# %%
knn_scaled = 0.4862846239937194
knn_pca = 0.5044641384881692

# %%
models = ("Linear Regression","KNN", "Decision Tree", "Random Forest", "Gradient Boosting", "Multi Layer Perceptron")
preprocessing = {
    'Scaled': (lr_scaled, knn_scaled, dt_scaled, rf_scaled, gb_scaled, mlp_scaled),
    'PCA': (lr_pca, knn_pca, dt_pca, rf_pca, gb_pca, mlp_pca),
}

x = np.arange(len(models))  
width = 0.25  
multiplier = 0

fig, ax = plt.subplots(layout='constrained')

for attribute, measurement in preprocessing.items():
    offset = width * multiplier
    rects = ax.bar(x + offset, measurement, width, label=attribute)
    ax.bar_label(rects, padding=3)
    multiplier += 1

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Mean Absolute Error')
ax.set_title('Comparison of Predictive Models [One Hot]')
ax.set_xticks(x + width, models, rotation=45)
ax.legend(loc='upper left', ncols=3)

plt.axhline(y=baseline, color='r', ls='--', label='Baseline')

plt.legend(loc='upper left')

plt.show()
