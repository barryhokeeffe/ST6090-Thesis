# %% [markdown]
# ##### Set Up

# %%
## imports and dependencies 

# standard libraries 
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt

# models
from sklearn.linear_model import LinearRegression

# data split
from sklearn.model_selection import train_test_split

# scaling 
from sklearn.preprocessing import StandardScaler

# PCA
from sklearn.decomposition import PCA

# accuracy
from sklearn.metrics import mean_absolute_error

# %% [markdown]
# ##### Data

# %%
# data
df = pd.read_csv("tar_enc_dataset.csv")

# %%
# feature reduction
df = df.drop(['Weekly Gross', 'Total Gross', 'Annual Gross', 'Weekly Net', 'Annual Net', 'Ln Annual Net', 'AgeSQ'], axis=1)

# %% [markdown]
# ##### Pre Processing

# %%
# parameters and target
x = df.drop('Ln Weekly Gross', axis=1)
y = df['Ln Weekly Gross']

# %%
# train test split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
# scale
scaler = StandardScaler()
x_train_scaled = scaler.fit_transform(x_train)
x_test_scaled = scaler.transform(x_test)

# %%
# PCA
pca = PCA(n_components=0.9) 
x_train_pca = pca.fit_transform(x_train_scaled)
x_test_pca = pca.transform(x_test_scaled)

# %%
# PCA
x_train_pca = pca.fit_transform(x_train_scaled)

# critical value
lst = []

# cumulative explained variance
cumulative_explained_variance = np.cumsum(pca.explained_variance_ratio_)

# iterate through different numbers of principal components
for i in range(1, len(cumulative_explained_variance) + 1):
    if cumulative_explained_variance[i-1] >= 0.9:
        lst.append(i)
    print("Number of Principal Components: " + str(1))
    print(f"Cumulative Explained Variance: {cumulative_explained_variance[i-1]}")
    print("")

# plot the cumulative explained variance
plt.plot(range(1, len(cumulative_explained_variance) + 1), cumulative_explained_variance, marker='o')
plt.plot(33, cumulative_explained_variance[32], color='r', marker='o', markersize=8)
plt.xlabel("Number of Principal Components")
plt.ylabel("Cumulative Explained Variance")
plt.axhline(y=0.9)
plt.title("Cumulative Explained Variance vs. Number of Principal Components")
plt.show()

print("Critical Principal Component: " + str(lst[0]))
# Out:
# Number of Principal Components: 1
# Cumulative Explained Variance: 0.35761530828029
#
# Number of Principal Components: 1
# Cumulative Explained Variance: 0.5186837335907982
#
# Number of Principal Components: 1
# Cumulative Explained Variance: 0.5729936145388871
#
# Number of Principal Components: 1
# Cumulative Explained Variance: 0.6164973928561306
#
# Number of Principal Components: 1
# Cumulative Explained Variance: 0.6478196055656469
#
# Number of Principal Components: 1
# Cumulative Explained Variance: 0.6721192938100917
#
# Number of Principal Components: 1
# Cumulative Explained Variance: 0.6910135778163582
#
# Number of Principal Components: 1
# Cumulative Explained Variance: 0.7078502411763912
#
# Number of Principal Components: 1
# Cumulative Explained Variance: 0.7235869005262924
#
# Number of Principal Components: 1
# Cumulative Explained Variance: 0.7389866937302344
#
# Number of Principal Components: 1
# Cumulative Explained Variance: 0.7516166182097471
#
# Number of Principal Components: 1
# Cumulative Explained Variance: 0.7633215316631701
#
# Number of Principal Components: 1
# Cumulative Explained Variance: 0.7738860784827295
#
# Number of Principal Components: 1
# Cumulative Explained Variance: 0.7838252784462306
#
# Number of Principal Components: 1
# Cumulative Explained Variance: 0.792829771200195
#
# Number of Principal Components: 1
# Cumulative Explained Variance: 0.8009460594278357
#
# Number of Principal Components: 1
# Cumulative Explained Variance: 0.8088579237019371
#
# Number of Principal Components: 1
# Cumulative Explained Variance: 0.8162667549317539
#
# Number of Principal Components: 1
# Cumulative Explained Variance: 0.8233916397238641
#
# Number of Principal Components: 1
# Cumulative Explained Variance: 0.8301741029751045
#
# Number of Principal Components: 1
# Cumulative Explained Variance: 0.8368112692494294
#
# Number of Principal Components: 1
# Cumulative Explained Variance: 0.8429786365380308
#
# Number of Principal Components: 1
# Cumulative Explained Variance: 0.8490800300295243
#
# Number of Principal Components: 1
# Cumulative Explained Variance: 0.8551293858165784
#
# Number of Principal Components: 1
# Cumulative Explained Variance: 0.8608157433779934
#
# Number of Principal Components: 1
# Cumulative Explained Variance: 0.8662767750739229
#
# Number of Principal Components: 1
# Cumulative Explained Variance: 0.871594123604342
#
# Number of Principal Components: 1
# Cumulative Explained Variance: 0.8767805557686236
#
# Number of Principal Components: 1
# Cumulative Explained Variance: 0.8817445137946606
#
# Number of Principal Components: 1
# Cumulative Explained Variance: 0.8866346797903232
#
# Number of Principal Components: 1
# Cumulative Explained Variance: 0.8912245316249068
#
# Number of Principal Components: 1
# Cumulative Explained Variance: 0.8957639055803793
#
# Number of Principal Components: 1
# Cumulative Explained Variance: 0.9000882828247512
# Critical Principal Component: 33

# %%
# Critical PCA
pca = PCA(n_components=33)
x_train_pca = pca.fit_transform(x_train_scaled)
x_test_pca = pca.transform(x_test_scaled)

# %% [markdown]
# ##### Models

# %%
# Linear Regressor 
LR = LinearRegression()

# %%
# PCA model
LR.fit(x_train_pca, y_train)
y_pred = LR.predict(x_test_pca)

mae = mean_absolute_error(y_test, y_pred)
print("Mean Absolute Error:", mae)
# Out:
# Mean Absolute Error: 0.4476347070027384

# %%
# scaled model
LR.fit(x_train_scaled, y_train)
y_pred = LR.predict(x_test_scaled)

mae_scaled = mean_absolute_error(y_test, y_pred)
print("Mean Absolute Error:", mae_scaled)
# Out:
# Mean Absolute Error: 0.4271470239143451

# %%
# iterate through values of n_components
num_components = []
mae_values = []

for i in range(1, len(cumulative_explained_variance) + 1):

    pca = PCA(n_components=33)
    x_train_pca = pca.fit_transform(x_train_scaled)
    x_test_pca = pca.transform(x_test_scaled)   

    LR = LinearRegression()

    LR.fit(x_train_pca, y_train)
    y_pred = LR.predict(x_test_pca)

    mae = mean_absolute_error(y_test, y_pred)
    num_components.append(i)
    mae_values.append(mae)

plt.plot(num_components, mae_values)
plt.axhline(y=mae_scaled, color='r', ls='--')
plt.xlabel("Number of Principal Components")
plt.ylabel("Mean Absolute Error")
plt.title("Mean Absolute Error vs. Number of Principal Components")
plt.show()

# %%
num_components[mae_values.index(min(mae_values))], min(mae_values)
# Out:
# (28, 0.444571173331888)
