# %% [markdown]
# ##### Set Up

# %%
## imports and dependencies 

# standard libraries 
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt

# models
from sklearn.linear_model import LinearRegression

# data split
from sklearn.model_selection import train_test_split

# scaling 
from sklearn.preprocessing import StandardScaler

# PCA
from sklearn.decomposition import PCA

# accuracy
from sklearn.metrics import mean_absolute_error

# %% [markdown]
# ##### Data

# %%
# data
df = pd.read_csv("region_dataset.csv")

# %%
# feature reduction
df = df.drop(['Name', 'Weekly Gross', 'Total Gross', 'Annual Gross', 'Weekly Net', 'Annual Net', 'Ln Annual Net', 'AgeSQ', 'Gen Pos_D', 'Gen Pos_M', 'Gen Pos_F'], axis=1)

# %% [markdown]
# ##### Pre Processing

# %%
# parameters and target
x = df.drop('Ln Weekly Gross', axis=1)
y = df['Ln Weekly Gross']

# %%
# train test split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
# scale
scaler = StandardScaler()
x_train_scaled = scaler.fit_transform(x_train)
x_test_scaled = scaler.transform(x_test)

# %%
# PCA
pca = PCA(n_components=0.9) 
x_train_pca = pca.fit_transform(x_train_scaled)
x_test_pca = pca.transform(x_test_scaled)

# %%
# PCA
x_train_pca = pca.fit_transform(x_train_scaled)

# critical value
lst = []

# cumulative explained variance
cumulative_explained_variance = np.cumsum(pca.explained_variance_ratio_)

# iterate through different numbers of principal components
for i in range(1, len(cumulative_explained_variance) + 1):
    if cumulative_explained_variance[i-1] >= 0.9:
        lst.append(i)
    print("Number of Principal Components: " + str(1))
    print(f"Cumulative Explained Variance: {cumulative_explained_variance[i-1]}")
    print("")

# plot the cumulative explained variance
plt.plot(range(1, len(cumulative_explained_variance) + 1), cumulative_explained_variance, marker='o')
plt.plot(33, cumulative_explained_variance[32], color='r', marker='o', markersize=8)
plt.xlabel("Number of Principal Components")
plt.ylabel("Cumulative Explained Variance")
plt.axhline(y=0.9)
plt.title("Cumulative Explained Variance vs. Number of Principal Components")
plt.show()

print("Critical Principal Component: " + str(lst[0]))
# Out:
# Number of Principal Components: 1
# Cumulative Explained Variance: 0.3159700430295751
#
# Number of Principal Components: 1
# Cumulative Explained Variance: 0.4569752016467941
#
# Number of Principal Components: 1
# Cumulative Explained Variance: 0.5059852978729926
#
# Number of Principal Components: 1
# Cumulative Explained Variance: 0.545140916694937
#
# Number of Principal Components: 1
# Cumulative Explained Variance: 0.5744339874949992
#
# Number of Principal Components: 1
# Cumulative Explained Variance: 0.5985095769557977
#
# Number of Principal Components: 1
# Cumulative Explained Variance: 0.617886990284872
#
# Number of Principal Components: 1
# Cumulative Explained Variance: 0.6345356861632642
#
# Number of Principal Components: 1
# Cumulative Explained Variance: 0.649216447756787
#
# Number of Principal Components: 1
# Cumulative Explained Variance: 0.663410999309704
#
# Number of Principal Components: 1
# Cumulative Explained Variance: 0.6753788524201126
#
# Number of Principal Components: 1
# Cumulative Explained Variance: 0.6862930284604927
#
# Number of Principal Components: 1
# Cumulative Explained Variance: 0.6964906551732499
#
# Number of Principal Components: 1
# Cumulative Explained Variance: 0.7063824717687077
#
# Number of Principal Components: 1
# Cumulative Explained Variance: 0.7157109651844213
#
# Number of Principal Components: 1
# Cumulative Explained Variance: 0.7243833240229445
#
# Number of Principal Components: 1
# Cumulative Explained Variance: 0.7326667235600143
#
# Number of Principal Components: 1
# Cumulative Explained Variance: 0.740682707278528
#
# Number of Principal Components: 1
# Cumulative Explained Variance: 0.7483333901480324
#
# Number of Principal Components: 1
# Cumulative Explained Variance: 0.7556836103986688
#
# Number of Principal Components: 1
# Cumulative Explained Variance: 0.7627953124915029
#
# Number of Principal Components: 1
# Cumulative Explained Variance: 0.769805949956334
#
# Number of Principal Components: 1
# Cumulative Explained Variance: 0.7765540102295692
#
# Number of Principal Components: 1
# Cumulative Explained Variance: 0.7832361299932696
#
# Number of Principal Components: 1
# Cumulative Explained Variance: 0.7897389269833679
#
# Number of Principal Components: 1
# Cumulative Explained Variance: 0.7960999677754907
#
# Number of Principal Components: 1
# Cumulative Explained Variance: 0.8024317098570585
#
# Number of Principal Components: 1
# Cumulative Explained Variance: 0.8086244265013601
#
# Number of Principal Components: 1
# Cumulative Explained Variance: 0.8146040071141829
#
# Number of Principal Components: 1
# Cumulative Explained Variance: 0.8205279946174084
#
# Number of Principal Components: 1
# Cumulative Explained Variance: 0.8264036554826745
#
# Number of Principal Components: 1
# Cumulative Explained Variance: 0.8321574898021434
#
# Number of Principal Components: 1
# Cumulative Explained Variance: 0.8378729676871738
#
# Number of Principal Components: 1
# Cumulative Explained Variance: 0.843470223322589
#
# Number of Principal Components: 1
# Cumulative Explained Variance: 0.8489455878091257
#
# Number of Principal Components: 1
# Cumulative Explained Variance: 0.8542910727508448
#
# Number of Principal Components: 1
# Cumulative Explained Variance: 0.8594978641282007
#
# Number of Principal Components: 1
# Cumulative Explained Variance: 0.8645423038515637
#
# Number of Principal Components: 1
# Cumulative Explained Variance: 0.869574383264292
#
# Number of Principal Components: 1
# Cumulative Explained Variance: 0.874297168745507
#
# Number of Principal Components: 1
# Cumulative Explained Variance: 0.8789074936078536
#
# Number of Principal Components: 1
# Cumulative Explained Variance: 0.8833804218890022
#
# Number of Principal Components: 1
# Cumulative Explained Variance: 0.8877863576463332
#
# Number of Principal Components: 1
# Cumulative Explained Variance: 0.8920308691718856
#
# Number of Principal Components: 1
# Cumulative Explained Variance: 0.8961070650025744
#
# Number of Principal Components: 1
# Cumulative Explained Variance: 0.9001649804386505
# Critical Principal Component: 46

# %%
# Critical PCA
pca = PCA(n_components=33)
x_train_pca = pca.fit_transform(x_train_scaled)
x_test_pca = pca.transform(x_test_scaled)

# %% [markdown]
# ##### Models

# %%
# Linear Regressor 
LR = LinearRegression()

# %%
# PCA model
LR.fit(x_train_pca, y_train)
y_pred = LR.predict(x_test_pca)

mae = mean_absolute_error(y_test, y_pred)
print("Mean Absolute Error:", mae)
# Out:
# Mean Absolute Error: 0.4993378149722977

# %%
# scaled model
LR.fit(x_train_scaled, y_train)
y_pred = LR.predict(x_test_scaled)

mae_scaled = mean_absolute_error(y_test, y_pred)
print("Mean Absolute Error:", mae_scaled)
# Out:
# Mean Absolute Error: 0.41890974513503815

# %%
# iterate through values of n_components
num_components = []
mae_values = []

for i in range(1, len(cumulative_explained_variance) + 1):

    pca = PCA(n_components=33)
    x_train_pca = pca.fit_transform(x_train_scaled)
    x_test_pca = pca.transform(x_test_scaled)   

    LR = LinearRegression()

    LR.fit(x_train_pca, y_train)
    y_pred = LR.predict(x_test_pca)

    mae = mean_absolute_error(y_test, y_pred)
    num_components.append(i)
    mae_values.append(mae)

plt.plot(num_components, mae_values)
plt.axhline(y=mae_scaled, color='r', ls='--')
plt.xlabel("Number of Principal Components")
plt.ylabel("Mean Absolute Error")
plt.title("Mean Absolute Error vs. Number of Principal Components")
plt.show()

# %%
num_components[mae_values.index(min(mae_values))], min(mae_values)
# Out:
# (36, 0.48622220231168073)
